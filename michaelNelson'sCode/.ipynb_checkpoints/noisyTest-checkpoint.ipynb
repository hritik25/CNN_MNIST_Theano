# %%
import network3
from network3 import Network
from network3 import ConvPoolLayer, FullyConnectedLayer, SoftmaxLayer
training_data, validation_data, test_data = network3.load_data_shared()
# Out:
# Using gpu device 0: GeForce GT 645M (CNMeM is disabled, cuDNN 5105)
# /usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Trying to run under a GPU.  If this is not desired, then modify network3.py
# to set the GPU flag to False.

# %%
import gzip, cPickle
f = gzip.open("../data/mnist.pkl.gz", 'rb')
training_data, validation_data, test_data = cPickle.load(f)
# Out:
# 784

# %%
training_data[0][0][1].nbytes
# Out:
# 4

# %%
import cPickle, gzip
filename="../data/mnist.pkl.gz"
f = gzip.open(filename, 'rb')
training_data, validation_data, test_data = cPickle.load(f)
type(training_data[1])
# Out:
# numpy.ndarray

# %%
mini_batch_size = 10
net = Network([
        FullyConnectedLayer(n_in=784, n_out=100),
        SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
net.SGD(training_data, 60, mini_batch_size, 0.1, 
            validation_data, test_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d2314b7b64aa> in <module>()
#       4         SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
#       5 net.SGD(training_data, 60, mini_batch_size, 0.1,
# ----> 6             validation_data, test_data)
#
# /home/hritik/neural-networks-and-deep-learning/src/network3.py in SGD(self, training_data, epochs, mini_batch_size, eta, validation_data, test_data, lmbda)
#      76
#      77         # compute number of minibatches for training, validation and testing
# ---> 78         num_training_batches = size(training_data)/mini_batch_size
#      79         num_validation_batches = size(validation_data)/mini_batch_size
#      80         num_test_batches = size(test_data)/mini_batch_size
#
# /home/hritik/neural-networks-and-deep-learning/src/network3.py in size(data)
#     263 def size(data):
# ...

# %%
mini_batch_size = 10
net = Network([
        FullyConnectedLayer(n_in=784, n_out=100, activation_fn=network3.ReLU),
        SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
net.SGD(training_data, 60, mini_batch_size, 0.1, 
            validation_data, test_data)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 95.17%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.73%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 95.73%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 95.23%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 96.12%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 95.94%
# Training mini-batch number 15000
# Training mini-batch number 16000
# ...

# %%
import noisyFunctions
from noisyFunctions import Network, FullyConnectedLayer, SoftmaxLayer, NSigmoid, NTanh
training_data, validation_data, test_data = noisyFunctions.load_data_shared()

# %%
# with noise turned off during test time
mini_batch_size = 10
net = Network([
        FullyConnectedLayer(n_in=784, n_out=100, activation_fn=NSigmoid),
        SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
net.SGD(training_data, 60, mini_batch_size, 0.1, 
            validation_data, test_data)
# Out:
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 90.82%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 90.60%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 93.34%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 92.71%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 94.69%
# ...

# %%
import network3WithNoisyUnits
from network3WithNoisyUnits import Network
from network3WithNoisyUnits import ConvPoolLayer, FullyConnectedLayer, SoftmaxLayer
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
# Out:
# Using gpu device 0: GeForce GT 645M (CNMeM is disabled, cuDNN not available)
# Trying to run under a GPU.  If this is not desired, then modify network3.py
# to set the GPU flag to False.

# %%
"""
The following network uses ReLU activation units and produced an
Best validation accuracy of 99.34% obtained at iteration 289999
Corresponding test accuracy was 99.43%.

mini_batch_size = 10
training_data, validation_data, test_data = load_data_shared()
net = Network([
        ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
                      filter_shape=(20, 1, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=ReLU),
        ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
                      filter_shape=(40, 20, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=ReLU),
        FullyConnectedLayer(
            n_in=40*4*4, n_out=100, activation_fn=ReLU, p_dropout=0.5),
        SoftmaxLayer(n_in=100, n_out=10, p_dropout=0.5)], 
        mini_batch_size)

net.SGD(training_data, 60, mini_batch_size, 0.03, 
            validation_data, test_data, lmbda = 0.1)
"""

# Now I will run the same network architecture with Noisy Activation Units (Basic Concept)
mini_batch_size = 10
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
net = Network([
        ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
                      filter_shape=(20, 1, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=NTanh),
        ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
                      filter_shape=(40, 20, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=NTanh),
        FullyConnectedLayer(
            n_in=40*4*4, n_out=100, activation_fn=NTanh, p_dropout=0.5),
        SoftmaxLayer(n_in=100, n_out=10, p_dropout=0.5)], 
        mini_batch_size)

net.SGD(training_data, 60, mini_batch_size, 0.03, 
            validation_data, test_data, lmbda = 0.1)
# Out:
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 95.09%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.94%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 96.73%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 96.93%
# Training mini-batch number 10000
# ...

# %%
mini_batch_size = 10
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
import sys
for noisyFunction in [ NHardTanh, NHardSigmoid, NHardTanhSat, NHardSigmoidSat ]:
    filename = noisyFunction.func_name + '.txt'
    with open(filename, 'w') as file:
        sys.stdout = file
        net = Network([
        ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
                      filter_shape=(20, 1, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=noisyFunction),
        ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
                      filter_shape=(40, 20, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=noisyFunction),
        FullyConnectedLayer(
            n_in=40*4*4, n_out=100, activation_fn=noisyFunction, p_dropout=0.5),
        SoftmaxLayer(n_in=100, n_out=10, p_dropout=0.5)], 
        mini_batch_size)
        net.SGD(training_data, 60, mini_batch_size, 0.03, 
            validation_data, test_data, lmbda = 0.1)
# Out:
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# ...

# %%
def printthis():
    print "this is a test"

with open('testing.txt', 'w') as f:
    sys.stdout = f
    printthis()

# %%
import network3WithNoisyUnits
from network3WithNoisyUnits import Network
from network3WithNoisyUnits import ConvPoolLayer, FullyConnectedLayer, SoftmaxLayer
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
from network3WithNoisyUnits import NReLU
mini_batch_size = 10
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
net = Network([
        ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
                      filter_shape=(20, 1, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=NReLU),
        ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
                      filter_shape=(40, 20, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=NReLU),
        FullyConnectedLayer(
            n_in=40*4*4, n_out=100, activation_fn=NReLU, p_dropout=0.5),
        SoftmaxLayer(n_in=100, n_out=10, p_dropout=0.5)], 
        mini_batch_size)

net.SGD(training_data, 60, mini_batch_size, 0.03, 
            validation_data, test_data, lmbda = 0.1)
# Out:
# Using gpu device 0: GeForce GT 645M (CNMeM is disabled, cuDNN not available)
# Trying to run under a GPU.  If this is not desired, then modify network3.py
# to set the GPU flag to False.
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 95.66%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 95.55%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# ...

# %%
import gzip, cPickle
f = gzip.open('data/mnist.pkl.gz', 'rb')
training_data, validation_data, test_data = cPickle.load(f)

# %%
len(test_data[0])
# Out:
# 10000

# %%
import network3WithNoisyUnits
from network3WithNoisyUnits import Network, FullyConnectedLayer, SoftmaxLayer, NReLU, NSigmoid, NTanh, NHardSigmoid, NHardTanh, NHardSigmoidSat, NHardTanhSat
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()

# %%
mini_batch_size = 10
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
import sys
for noisyFunction in [ NSigmoid, NTanh, NReLU, NHardTanh, NHardSigmoid, NHardTanhSat, NHardSigmoidSat ]:
    filename = 'feedforward' + noisyFunction.func_name + '.txt'
    with open(filename, 'w') as file:
        sys.stdout = file
        net = Network([
            FullyConnectedLayer(n_in=784, n_out=100, activation_fn=noisyFunction),
            SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
        net.SGD(training_data, 60, mini_batch_size, 0.1, 
            validation_data, test_data)
# Out:
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.500000
# INFO:Noisy Units Logger:c: 0.500000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.050000
# INFO:Noisy Units Logger:c: 0.050000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0.250000
# INFO:Noisy Units Logger:c: 0.250000
# c: 0
# INFO:Noisy Units Logger:c: 0
# c: 0
# ...

# %%
mini_batch_size = 10
import network3WithNoisyUnits
from network3WithNoisyUnits import Network, FullyConnectedLayer, SoftmaxLayer, tanh
training_data, validation_data, test_data = network3WithNoisyUnits.load_data_shared()
net = Network([
        FullyConnectedLayer(n_in=784, n_out=100, activation_fn=tanh),
        SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
net.SGD(training_data, 60, mini_batch_size, 0.1, 
    validation_data, test_data)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 95.27%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.96%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 96.29%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 96.09%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 96.67%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 96.56%
# Training mini-batch number 15000
# Training mini-batch number 16000
# ...

# %%
mini_batch_size = 10
from network3WithNoisyUnits import ConvPoolLayer
net = Network([
        ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
                      filter_shape=(20, 1, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=tanh),
        ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
                      filter_shape=(40, 20, 5, 5), 
                      poolsize=(2, 2), 
                      activation_fn=tanh),
        FullyConnectedLayer(
            n_in=40*4*4, n_out=100, activation_fn=tanh, p_dropout=0.5),
        SoftmaxLayer(n_in=100, n_out=10, p_dropout=0.5)], 
        mini_batch_size)

net.SGD(training_data, 60, mini_batch_size, 0.03, 
            validation_data, test_data, lmbda = 0.1)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 95.72%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 95.52%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 97.08%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 97.09%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 97.82%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 97.87%
# Training mini-batch number 15000
# Training mini-batch number 16000
# ...
